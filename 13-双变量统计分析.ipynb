# %%
import mytools

# %%
mytools.render(mytools.dsllm("goodmanKruska 的tau_y"))
# Out:
# ```thinking
# Hmm, the term "goodmanKruska" seems to be a combination of two names, Goodman and Kruska. This could potentially refer to a specific concept or model that combines the work or ideas of these two individuals. The "tau_y" part seems to be a variable or parameter, possibly related to some kind of mathematical or statistical model.
#
# Let's consider the broader context. Goodman and Kruska could be researchers or theorists in a specific field, and "tau_y" might be a term they introduced in their work. The field could be statistics, economics, or even physics, depending on the nature of their research.
#
# I need to explore if there are any known models or theories associated with these names. If they are indeed researchers, their work might be documented in academic papers or books.
#
# ...

# %%
mytools.calling_the_roll(r'stu\2023级广告学1班学生名单.xlsx')
# Out:
# 随机抽取的学生姓名是: 胥曼
# c:\Program Files\Python38\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
